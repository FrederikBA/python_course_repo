# %%
import exercise01
import pandas as pd
import matplotlib.pyplot as plt

unmarried = exercise01.marrital_status()[0].to_dict()
married = exercise01.marrital_status()[1].to_dict()
divorced = exercise01.marrital_status()[2].to_dict()
widows = exercise01.marrital_status()[3].to_dict()


keys = list(unmarried.keys())
unmarried_values = list(unmarried.values())

married_values = list(married.values())

divorced_values = list(divorced.values())

widows_values = list(widows.values())

plt.plot(keys, unmarried_values, label = "Unmarried")
plt.plot(keys, married_values, label = "Married")
plt.plot(keys, divorced_values, label = "Divorced")
plt.plot(keys, widows_values, label = "Widows")
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')
plt.xlabel('Year', fontweight='bold')
plt.ylabel('Population in millions', fontweight='bold')
plt.legend()
plt.show()

# %%
import exercise01
import pandas as pd
import matplotlib.pyplot as plt

unmarried = exercise01.marriage_status_2020()[0].to_dict()
married = exercise01.marriage_status_2020()[1].to_dict()


keys = list(unmarried.keys())

unmarried_values = list(unmarried.values())
married_values = list(married.values())
plt.plot(keys, unmarried_values, label = "Unmarried")
plt.plot(keys, married_values, label = "Married")
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')
plt.ylabel('Citizens', fontweight='bold')
plt.xlabel('Age', fontweight='bold')
plt.legend()
plt.show()
